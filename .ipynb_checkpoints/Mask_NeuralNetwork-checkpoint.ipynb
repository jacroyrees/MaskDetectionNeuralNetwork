# %%
#Import all of the packages that are needed
import time
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # default plot sizes
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
hf = h5py.File('mask_dataset.hdf5', 'r')

# %%
list(hf.keys())
# Out:
# ['test_img', 'test_labels', 'train_img', 'train_labels']

# %%
with h5py.File('mask_dataset.hdf5', 'r') as hf:
    X_test = hf['test_img'][()]
    Y_test = hf['test_labels'][()]
    X_train = hf['train_img'][()]
    Y_train = hf['train_labels'][()]

# %%
m_train = X_train.shape[0]
m_test = X_test.shape[0]
#Each image is of size 128, 128, 3
num_px = 128

# %%
index = 10
plt.imshow(X_train[83])

# %%
print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_x_orig shape: " + str(X_train.shape))
print ("train_y shape: " + str(Y_train.shape))
print ("test_x_orig shape: " + str(X_test.shape))
print ("test_y shape: " + str(Y_test.shape))
# Out:
# Number of training examples: 954
# Number of testing examples: 239
# Each image is of size: (128, 128, 3)
# train_x_orig shape: (954, 128, 128, 3)
# train_y shape: (954,)
# test_x_orig shape: (239, 128, 128, 3)
# test_y shape: (239,)

# %%
# Out:
# train_x's shape: (49152, 954)
# test_x's shape: (49152, 239)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-5191145e9124> in <module>
# ----> 1 parameters = L_layer_model(train_X, train_X, layer_dims, num_iterations = 2500, print_cost = True)
#
# <ipython-input-109-159983733840> in L_layer_model(X, Y, layers_dims, learning_rate, num_iterations, print_cost)
#      27         # Forward propagation: [LINEAR -> RELU]*(L-1) -> LINEAR -> SIGMOID.
#      28
# ---> 29         AL, caches = L_model_forward(X, parameters)
#      30
#      31
#
# <ipython-input-106-8b731d103b40> in L_model_forward(X, parameters)
#      64         A_prev = A
#      65
# ---> 66         A, cache = linear_activation_forward(A_prev,
#      67                                              parameters['W' + str(l)],
#      68                                              parameters['b' + str(l)],
#
# <ipython-input-106-8b731d103b40> in linear_activation_forward(A_prev, W, b, activation)
#      13         ### START CODE HERE ### (≈ 2 lines of code)
#      14         Z, linear_cache = linear_forward(A_prev, W, b)
# ---> 15         A, activation_cache = relu(Z)
#      16         ### END CODE HERE ###
#      17
#
# <ipython-input-105-7789e913c149> in relu(z)
#       3     return s
#       4 def relu(z):
# ----> 5     z = 1 / (1+ np.exp(-np.dot(W, A) + b))
#       6
#       7 def initialize_parameters_deep(layers_dims):
#
# NameError: name 'W' is not defined
